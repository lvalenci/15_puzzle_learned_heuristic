# %%
'''
Worked on by: Meena Hari and Tarini Singh.

Trained KNearestNeighbors on "All_Data.txt"
with K=[1,2,3,4,5, 6, 7, 10, 15, 20, 25, 30, 35, 50, 100, 300].

Made predictions using 1) arithmetic mean of 
neighbors' predictions, 2) geometric mean of 
neighbors' predictions, and 3) harmonic mean of 
neighbors' predictions.

Tested model on "Test_boards.txt" and recorded
various performance metrics (e.g. # times overestimated 
true output, # of times overestimated manhattan 
heuristic) of the models in order to find the optimal 
K and type of mean to use in making predictions.
'''

from numba import njit, jit
from scipy import stats
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from tqdm import tqdm
import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv2D, Flatten, Input
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from keras.models import load_model
import keras.losses

from constants import *
import heuristic as h
import io_help as io
import neural_net as nn
import solver as s

def load_data(file_name):
    """
    Reads in training data from a file and returns 
    the boards in X and their labels in Y as a tuple. 
    (Function copied from "neural_net.py").
    """
    file = open(file_name, "r")
    X = []
    Y = []
    
    for string in file: 
        (board, dist) = io.string_to_board_and_dist(string)
        X_temp = np.concatenate((board.reshape(16)), axis=None)
        X.append(X_temp)
        Y.append(dist)
        
    file.close()
    X_train = np.asarray(X)
    Y_train = np.asarray(Y)
    return(X_train, Y_train)
# Out:
# Using TensorFlow backend.

# %%
def knn_test(X_test, X_train, Y_train, model):
    '''
    Returns model's predictions on X_test as a 
    numpy array of size: (# testing samples) x 3.
    
    X test: array of test boards, each with size (16,)
    X_train: array of training boards, each with size (16,)
    Y_train: array of true output for X_train.
    model: array of k-nearest neighbors for X_train generated by trained knn model.
    
    1st column of predictions is generated using arithmetic
    mean.
    2nd column of predictions is generated using geometric
    mean.
    3rd column of predictions is generated using harmonic
    mean.
    '''
    
    # Stores predictions of the knn model.
    preds = np.zeros((len(X_test),3))

    for i in range(len(X_test)):
        neigh_inds = model[1][i]
        res_mean = np.mean(Y_train[neigh_inds])
        res_gmean = stats.gmean(Y_train[neigh_inds])
        res_hmean = stats.hmean(Y_train[neigh_inds])
        preds[i, 0] = res_mean
        preds[i, 1] = res_gmean
        preds[i, 2] = res_hmean
        #mode = stats.mode(Y_train[neigh_inds])[0][0]
        
    return preds

# %%
def string_to_test_info(string):
    """
    Given a string containing the standard form of test info, returns tuple of 
    board, number of states to solution, time, and lenght of solution.
    (Function copied from "run_testing.py").
    """
    split = string.split("!")
    board = io.string_to_board(split[0])
    n_states = int(split[1])
    time = float(split[2])
    sol_len = int(split[3])
    return (board, n_states, time, sol_len)

def load_boards(filename):
    """
    Given name of file containing test boards, loads all test boards.
    (Function copied from "run_testing.py").
    """
    file = open(filename, "r")

    boards = []
    n_states = []
    times = []
    dists = []

    for line in file:
        (board, c_states, c_time, sol_len) = string_to_test_info(line)
        boards.append(board)
        n_states.append(c_states)
        times.append(c_time)
        dists.append(sol_len)

    return (boards, n_states, times, dists)

# %%
# Load dataset. X: board inputs, Y: true output.
(X_train,Y_train) = load_data('All_Data.txt')
print(X_train.shape)
# Out:
# (395715, 16)

# %%
# Load test boards.
(X_test_mt,_,_, Y_test) = load_boards('Test_boards.txt')
X_test = np.asarray(X_test_mt).reshape(len(X_test_mt),16)

# %%
# K-values to try during model training.
K = [1,2,3,4,5, 6, 7, 10, 15, 20, 25, 30, 35, 50, 100, 300]

# Store some statistics from model training to use for plotting.
avg_e_admiss_mean = []
perc_over_man_mean = []
perc_under_man_mean = []
perc_over_ham_mean = []


avg_e_admiss_gmean = []
perc_over_man_gmean = []
perc_under_man_gmean = []
perc_over_ham_gmean = []

# due to previous trials these are named with the suffix "mode"; think
# of this as representing "hmean" instead.
avg_e_admiss_mode = []
perc_over_man_mode = []
perc_under_man_mode = []
perc_over_ham_mode = []

# %%
for g in range(len(K)):
    print("Starting next K...")
    NEIGHBORS = K[g]
    
    # Generate knn model for g neighbors on X_train.
    knn_model = NearestNeighbors(n_neighbors=NEIGHBORS, n_jobs = -1).fit(X_train,Y_train)
    
    # Get neighbors of test samples.
    pred = knn_model.kneighbors(X_test)
    # Get predictions on test samples.
    model = knn_test(X_test, X_train, Y_train, pred)
    
    #### Calculating heuristics/statistics. ####
    
    # stats for knn with truncation + arithmetic mean.
    dist_over_mean_i = []
    misclass_mean_i = 0
    dist_under_mean_i = []
    dist_over_man_mean_i = []
    dist_under_man_mean_i = []

    dist_over_ham_mean_i = []
    dist_under_ham_mean_i = []
    
    # stats for knn with truncation + gmean.
    dist_over_gmean_i = []
    misclass_gmean_i = 0
    dist_under_gmean_i = []
    dist_over_man_gmean_i = []
    dist_under_man_gmean_i = []

    dist_over_ham_gmean_i = []
    dist_under_ham_gmean_i = []
    
    # stats for knn with truncation + mode.
    dist_over_mode_i = []
    misclass_mode_i = 0
    dist_under_mode_i = []
    dist_over_man_mode_i = []
    dist_under_man_mode_i = []

    dist_over_ham_mode_i = []
    dist_under_ham_mode_i = []

    print("Starting stats for K: {} ...".format(NEIGHBORS))
    for i in range(len(X_test)):
        # Calculate knn prediction with mean.
        nn_heur_mean_i = int(model[i, 0])

        # Calculate knn prediction with geometric mean.
        nn_heur_gmean_i = int(model[i, 1])

        # Calculate knn prediction with mode.
        nn_heur_mode_i = int(model[i, 2])
        
        # Calculate Manhattan dist.
        man_heur = h.manhattan(X_test[i].reshape(4,4), None)
        # Calculate Hamming dist.
        ham_heur = h.hamming(X_test[i].reshape(4,4), None)
        y = Y_test[i]

        ### TRUNCATE ###
        
        # knn with mean.
        if (nn_heur_mean_i > y):
            dist_over_mean_i.append(nn_heur_mean_i - y)

        if (nn_heur_mean_i <= y):
            dist_under_mean_i.append(y - nn_heur_mean_i)

        if (nn_heur_mean_i != y):
            misclass_mean_i += 1

        if (nn_heur_mean_i > man_heur):
            dist_over_man_mean_i.append(nn_heur_mean_i - man_heur)

        if (nn_heur_mean_i < man_heur):
            dist_under_man_mean_i.append(man_heur - nn_heur_mean_i)

        if (nn_heur_mean_i > ham_heur):
            dist_over_ham_mean_i.append(nn_heur_mean_i - ham_heur)

        if (nn_heur_mean_i < ham_heur):
            dist_under_ham_mean_i.append(ham_heur - nn_heur_mean_i)


        # knn with gmean. 
        if (nn_heur_gmean_i > y):
            dist_over_gmean_i.append(nn_heur_gmean_i - y)

        if (nn_heur_gmean_i <= y):
            dist_under_gmean_i.append(y - nn_heur_gmean_i)

        if (nn_heur_gmean_i != y):
            misclass_gmean_i += 1

        if (nn_heur_gmean_i > man_heur):
            dist_over_man_gmean_i.append(nn_heur_gmean_i - man_heur)

        if (nn_heur_gmean_i < man_heur):
            dist_under_man_gmean_i.append(man_heur - nn_heur_gmean_i)

        if (nn_heur_gmean_i > ham_heur):
            dist_over_ham_gmean_i.append(nn_heur_gmean_i - ham_heur)

        if (nn_heur_gmean_i < ham_heur):
            dist_under_ham_gmean_i.append(ham_heur - nn_heur_gmean_i)    
            
        
        # knn with hmean.
        if (nn_heur_mode_i > y):
            dist_over_mode_i.append(nn_heur_mode_i - y)

        if (nn_heur_mode_i <= y):
            dist_under_mode_i.append(y - nn_heur_mode_i)

        if (nn_heur_mode_i != y):
            misclass_mode_i += 1

        if (nn_heur_mode_i > man_heur):
            dist_over_man_mode_i.append(nn_heur_mode_i - man_heur)

        if (nn_heur_mode_i < man_heur):
            dist_under_man_mode_i.append(man_heur - nn_heur_mode_i)

        if (nn_heur_mode_i > ham_heur):
            dist_over_ham_mode_i.append(nn_heur_mode_i - ham_heur)

        if (nn_heur_mode_i < ham_heur):
            dist_under_ham_mode_i.append(ham_heur - nn_heur_mode_i)
        
        
        
    # Averages for truncation + mean.
    avg_dist_over_mean_i = np.mean(np.asarray(dist_over_mean_i))
    avg_dist_under_mean_i = np.mean(np.asarray(dist_under_mean_i))
    out_sample_error_mean_i = misclass_mean_i / len(X_test)
    avg_dist_over_man_mean_i = np.mean(np.asarray(dist_over_man_mean_i))
    avg_dist_under_man_mean_i = np.mean(np.asarray(dist_under_man_mean_i))

    avg_dist_over_ham_mean_i = np.mean(np.asarray(dist_over_ham_mean_i))
    avg_dist_under_ham_mean_i = np.mean(np.asarray(dist_under_ham_mean_i))
    
    # Averages for truncation + gmean.
    avg_dist_over_gmean_i = np.mean(np.asarray(dist_over_gmean_i))
    avg_dist_under_gmean_i = np.mean(np.asarray(dist_under_gmean_i))
    out_sample_error_gmean_i = misclass_gmean_i / len(X_test)
    avg_dist_over_man_gmean_i = np.mean(np.asarray(dist_over_man_gmean_i))
    avg_dist_under_man_gmean_i = np.mean(np.asarray(dist_under_man_gmean_i))

    avg_dist_over_ham_gmean_i = np.mean(np.asarray(dist_over_ham_gmean_i))
    avg_dist_under_ham_gmean_i = np.mean(np.asarray(dist_under_ham_gmean_i))
    
    # Averages for truncation + hmean.
    avg_dist_over_mode_i = np.mean(np.asarray(dist_over_mode_i))
    avg_dist_under_mode_i = np.mean(np.asarray(dist_under_mode_i))
    out_sample_error_mode_i = misclass_mode_i / len(X_test)
    avg_dist_over_man_mode_i = np.mean(np.asarray(dist_over_man_mode_i))
    avg_dist_under_man_mode_i = np.mean(np.asarray(dist_under_man_mode_i))

    avg_dist_over_ham_mode_i = np.mean(np.asarray(dist_over_ham_mode_i))
    avg_dist_under_ham_mode_i = np.mean(np.asarray(dist_under_ham_mode_i))

    
    # Append stats for later plotting.
    avg_e_admiss_mean.append(len(dist_over_mean_i)/len(X_test))
    perc_over_man_mean.append(len(dist_over_man_mean_i)/len(X_test))
    perc_under_man_mean.append(len(dist_under_man_mean_i)/len(X_test))
    perc_over_ham_mean.append(len(dist_over_ham_mean_i)/len(X_test))
    
    avg_e_admiss_gmean.append(len(dist_over_gmean_i)/len(X_test))
    perc_over_man_gmean.append(len(dist_over_man_gmean_i)/len(X_test))
    perc_under_man_gmean.append(len(dist_under_man_gmean_i)/len(X_test))
    perc_over_ham_gmean.append(len(dist_over_ham_gmean_i)/len(X_test))
    
    avg_e_admiss_mode.append(len(dist_over_mode_i)/len(X_test))
    perc_over_man_mode.append(len(dist_over_man_mode_i)/len(X_test))
    perc_under_man_mode.append(len(dist_under_man_mode_i)/len(X_test))
    perc_over_ham_mode.append(len(dist_over_ham_mode_i)/len(X_test))
    
    
    print("------ TRUCATION - KNN with Mean: ------")
    print("Avg distance overestimated: ", avg_dist_over_mean_i)
    print("Avg distance underestimated: ", avg_dist_under_mean_i)
    print("E_admiss: ", len(dist_over_mean_i)/len(X_test))
    print("E_out: ", out_sample_error_mean_i)
    print("Avg distance over Manhattan: ", avg_dist_over_man_mean_i)
    print("Avg distance under Manhattan: ", avg_dist_under_man_mean_i)
    print("Percent over Manhattan: ", len(dist_over_man_mean_i)/len(X_test))
    print("Percent under Manhattan: ", len(dist_under_man_mean_i)/len(X_test))

    print("Avg distance over Hamming: ", avg_dist_over_ham_mean_i)
    print("Avg distance under Hamming: ", avg_dist_under_ham_mean_i)
    print("Percent over Hamming: ", len(dist_over_ham_mean_i)/len(X_test))
    print("Percent under Hamming: ", len(dist_under_ham_mean_i)/len(X_test))

    print("\n")
    print("------ TRUCATION - KNN with Gmean: ------")
    print("Avg distance overestimated: ", avg_dist_over_gmean_i)
    print("Avg distance underestimated: ", avg_dist_under_gmean_i)
    print("E_admiss: ", len(dist_over_gmean_i)/len(X_test) * 100)
    print("E_out: ", out_sample_error_gmean_i)
    print("Avg distance over Manhattan: ", avg_dist_over_man_gmean_i)
    print("Avg distance under Manhattan: ", avg_dist_under_man_gmean_i)
    print("Percent over Manhattan: ", len(dist_over_man_gmean_i)/len(X_test) * 100)
    print("Percent under Manhattan: ", len(dist_under_man_gmean_i)/len(X_test) * 100)

    print("Avg distance over Hamming: ", avg_dist_over_ham_gmean_i)
    print("Avg distance under Hamming: ", avg_dist_under_ham_gmean_i)
    print("Percent over Hamming: ", len(dist_over_ham_gmean_i)/len(X_test) * 100)
    print("Percent under Hamming: ", len(dist_under_ham_gmean_i)/len(X_test) * 100)
    
    print("\n")
    print("------ TRUCATION - KNN with HMean: ------")
    print("Avg distance overestimated: ", avg_dist_over_mode_i)
    print("Avg distance underestimated: ", avg_dist_under_mode_i)
    print("E_admiss: ", len(dist_over_mode_i)/len(X_test))
    print("E_out: ", out_sample_error_mode_i)
    print("Avg distance over Manhattan: ", avg_dist_over_man_mode_i)
    print("Avg distance under Manhattan: ", avg_dist_under_man_mode_i)
    print("Percent over Manhattan: ", len(dist_over_man_mode_i)/len(X_test) * 100)
    print("Percent under Manhattan: ", len(dist_under_man_mode_i)/len(X_test) * 100)

    print("Avg distance over Hamming: ", avg_dist_over_ham_mode_i)
    print("Avg distance under Hamming: ", avg_dist_under_ham_mode_i)
    print("Percent over Hamming: ", len(dist_over_ham_mode_i)/len(X_test) * 100)
    print("Percent under Hamming: ", len(dist_under_ham_mode_i)/len(X_test) * 100)
    
    print("\n")
    print("\n")
# Out:
# Starting next K...
# Starting stats for K: 1 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  3.864864864864865
# Avg distance underestimated:  7.8357705286839145
# E_admiss:  0.111
# E_out:  0.912
# Avg distance over Manhattan:  5.1097804391217565
# Avg distance under Manhattan:  4.024725274725275
# Percent over Manhattan:  0.501
# Percent under Manhattan:  0.364
# Avg distance over Hamming:  9.720528455284553
# Avg distance under Hamming:  2.0
# Percent over Hamming:  0.984
# Percent under Hamming:  0.007
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  3.710280373831776
# Avg distance underestimated:  8.301231802911534
# E_admiss:  10.7
# E_out:  0.938
# Avg distance over Manhattan:  4.7847082494969815
# Avg distance under Manhattan:  4.0228310502283104
# Percent over Manhattan:  49.7
# Percent under Manhattan:  43.8
# Avg distance over Hamming:  9.302968270214944
# Avg distance under Hamming:  2.125
# Percent over Hamming:  97.7
# Percent under Hamming:  0.8
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  3.864864864864865
# Avg distance underestimated:  7.8357705286839145
# E_admiss:  0.111
# E_out:  0.912
# Avg distance over Manhattan:  5.1097804391217565
# Avg distance under Manhattan:  4.024725274725275
# Percent over Manhattan:  50.1
# Percent under Manhattan:  36.4
# Avg distance over Hamming:  9.720528455284553
# Avg distance under Hamming:  2.0
# Percent over Hamming:  98.4
# Percent under Hamming:  0.7000000000000001
#
#
#
#
# Starting next K...
# Starting stats for K: 2 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  3.253012048192771
# Avg distance underestimated:  7.890948745910578
# E_admiss:  0.083
# E_out:  0.943
# Avg distance over Manhattan:  4.055226824457594
# Avg distance under Manhattan:  3.545918367346939
# Percent over Manhattan:  0.507
# Percent under Manhattan:  0.392
# Avg distance over Hamming:  9.28150406504065
# Avg distance under Hamming:  2.2
# Percent over Hamming:  0.984
# Percent under Hamming:  0.005
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  3.365079365079365
# Avg distance underestimated:  8.461045891141943
# E_admiss:  6.3
# E_out:  0.957
# Avg distance over Manhattan:  3.7986270022883297
# Avg distance under Manhattan:  3.750537634408602
# Percent over Manhattan:  43.7
# Percent under Manhattan:  46.5
# Avg distance over Hamming:  8.62962962962963
# Avg distance under Hamming:  2.0
# Percent over Hamming:  97.2
# Percent under Hamming:  0.8
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  3.274193548387097
# Avg distance underestimated:  8.478678038379531
# E_admiss:  0.062
# E_out:  0.951
# Avg distance over Manhattan:  3.747072599531616
# Avg distance under Manhattan:  3.792494481236203
# Percent over Manhattan:  42.699999999999996
# Percent under Manhattan:  45.300000000000004
# Avg distance over Hamming:  8.556352459016393
# Avg distance under Hamming:  1.8571428571428572
# Percent over Hamming:  97.6
# Percent under Hamming:  0.7000000000000001
#
#
#
#
# Starting next K...
# Starting stats for K: 3 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  3.0317460317460316
# Avg distance underestimated:  7.92102454642476
# E_admiss:  0.063
# E_out:  0.948
# Avg distance over Manhattan:  3.8620689655172415
# Avg distance under Manhattan:  3.4261083743842367
# Percent over Manhattan:  0.464
# Percent under Manhattan:  0.406
# Avg distance over Hamming:  9.051020408163266
# Avg distance under Hamming:  1.8571428571428572
# Percent over Hamming:  0.98
# Percent under Hamming:  0.007
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  2.9622641509433962
# Avg distance underestimated:  8.31467793030623
# E_admiss:  5.3
# E_out:  0.966
# Avg distance over Manhattan:  3.604651162790698
# Avg distance under Manhattan:  3.456659619450317
# Percent over Manhattan:  43.0
# Percent under Manhattan:  47.3
# Avg distance over Hamming:  8.568947906026558
# Avg distance under Hamming:  2.0
# Percent over Hamming:  97.89999999999999
# Percent under Hamming:  0.8999999999999999
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  2.9375
# Avg distance underestimated:  8.491596638655462
# E_admiss:  0.048
# E_out:  0.971
# Avg distance over Manhattan:  3.5369458128078817
# Avg distance under Manhattan:  3.5436105476673427
# Percent over Manhattan:  40.6
# Percent under Manhattan:  49.3
# Avg distance over Hamming:  8.36577868852459
# Avg distance under Hamming:  1.8181818181818181
# Percent over Hamming:  97.6
# Percent under Hamming:  1.0999999999999999
#
#
#
#
# Starting next K...
# Starting stats for K: 4 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  2.7758620689655173
# Avg distance underestimated:  7.886411889596603
# E_admiss:  0.058
# E_out:  0.954
# Avg distance over Manhattan:  3.5144628099173554
# Avg distance under Manhattan:  3.23728813559322
# Percent over Manhattan:  0.484
# Percent under Manhattan:  0.413
# Avg distance over Hamming:  9.024514811031665
# Avg distance under Hamming:  1.5
# Percent over Hamming:  0.979
# Percent under Hamming:  0.01
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  2.5319148936170213
# Avg distance underestimated:  8.31794333683106
# E_admiss:  4.7
# E_out:  0.96
# Avg distance over Manhattan:  3.30607476635514
# Avg distance under Manhattan:  3.4511930585683297
# Percent over Manhattan:  42.8
# Percent under Manhattan:  46.1
# Avg distance over Hamming:  8.506147540983607
# Avg distance under Hamming:  1.8333333333333333
# Percent over Hamming:  97.6
# Percent under Hamming:  1.2
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  2.5789473684210527
# Avg distance underestimated:  8.53118503118503
# E_admiss:  0.038
# E_out:  0.964
# Avg distance over Manhattan:  3.213197969543147
# Avg distance under Manhattan:  3.507042253521127
# Percent over Manhattan:  39.4
# Percent under Manhattan:  49.7
# Avg distance over Hamming:  8.191402251791198
# Avg distance under Hamming:  1.6
# Percent over Hamming:  97.7
# Percent under Hamming:  1.5
#
#
#
#
# Starting next K...
# Starting stats for K: 5 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  2.4705882352941178
# Avg distance underestimated:  8.008429926238145
# E_admiss:  0.051
# E_out:  0.951
# Avg distance over Manhattan:  3.4523281596452327
# Avg distance under Manhattan:  3.323040380047506
# Percent over Manhattan:  0.451
# Percent under Manhattan:  0.421
# Avg distance over Hamming:  8.825153374233128
# Avg distance under Hamming:  1.5454545454545454
# Percent over Hamming:  0.978
# Percent under Hamming:  0.011
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  2.3333333333333335
# Avg distance underestimated:  8.341311134235172
# E_admiss:  3.9
# E_out:  0.958
# Avg distance over Manhattan:  3.238442822384428
# Avg distance under Manhattan:  3.411764705882353
# Percent over Manhattan:  41.099999999999994
# Percent under Manhattan:  47.599999999999994
# Avg distance over Hamming:  8.396923076923077
# Avg distance under Hamming:  1.8461538461538463
# Percent over Hamming:  97.5
# Percent under Hamming:  1.3
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  2.242424242424242
# Avg distance underestimated:  8.640124095139607
# E_admiss:  0.033
# E_out:  0.967
# Avg distance over Manhattan:  3.0822281167108754
# Avg distance under Manhattan:  3.530214424951267
# Percent over Manhattan:  37.7
# Percent under Manhattan:  51.300000000000004
# Avg distance over Hamming:  8.056584362139917
# Avg distance under Hamming:  1.8461538461538463
# Percent over Hamming:  97.2
# Percent under Hamming:  1.3
#
#
#
#
# Starting next K...
# Starting stats for K: 6 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  2.58974358974359
# Avg distance underestimated:  8.0
# E_admiss:  0.039
# E_out:  0.961
# Avg distance over Manhattan:  3.2666666666666666
# Avg distance under Manhattan:  3.2312925170068025
# Percent over Manhattan:  0.45
# Percent under Manhattan:  0.441
# Avg distance over Hamming:  8.668362156663276
# Avg distance under Hamming:  1.6666666666666667
# Percent over Hamming:  0.983
# Percent under Hamming:  0.012
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  2.3333333333333335
# Avg distance underestimated:  8.446742502585316
# E_admiss:  3.3000000000000003
# E_out:  0.974
# Avg distance over Manhattan:  3.0675
# Avg distance under Manhattan:  3.4129554655870447
# Percent over Manhattan:  40.0
# Percent under Manhattan:  49.4
# Avg distance over Hamming:  8.239219712525667
# Avg distance under Hamming:  2.0
# Percent over Hamming:  97.39999999999999
# Percent under Hamming:  1.4000000000000001
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  2.1785714285714284
# Avg distance underestimated:  8.760288065843621
# E_admiss:  0.028
# E_out:  0.973
# Avg distance over Manhattan:  2.946927374301676
# Avg distance under Manhattan:  3.521575984990619
# Percent over Manhattan:  35.8
# Percent under Manhattan:  53.300000000000004
# Avg distance over Hamming:  7.872559095580678
# Avg distance under Hamming:  2.1666666666666665
# Percent over Hamming:  97.3
# Percent under Hamming:  1.2
#
#
#
#
# Starting next K...
# Starting stats for K: 7 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  2.358974358974359
# Avg distance underestimated:  8.14360041623309
# E_admiss:  0.039
# E_out:  0.967
# Avg distance over Manhattan:  3.1586206896551725
# Avg distance under Manhattan:  3.208695652173913
# Percent over Manhattan:  0.435
# Percent under Manhattan:  0.46
# Avg distance over Hamming:  8.565439672801636
# Avg distance under Hamming:  1.9166666666666667
# Percent over Hamming:  0.978
# Percent under Hamming:  0.012
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  2.2413793103448274
# Avg distance underestimated:  8.537590113285273
# E_admiss:  2.9000000000000004
# E_out:  0.971
# Avg distance over Manhattan:  3.0
# Avg distance under Manhattan:  3.398821218074656
# Percent over Manhattan:  37.9
# Percent under Manhattan:  50.9
# Avg distance over Hamming:  8.10164271047228
# Avg distance under Hamming:  2.0
# Percent over Hamming:  97.39999999999999
# Percent under Hamming:  1.4000000000000001
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.8518518518518519
# Avg distance underestimated:  8.899280575539569
# E_admiss:  0.027
# E_out:  0.979
# Avg distance over Manhattan:  2.857142857142857
# Avg distance under Manhattan:  3.571167883211679
# Percent over Manhattan:  34.300000000000004
# Percent under Manhattan:  54.800000000000004
# Avg distance over Hamming:  7.708418891170431
# Avg distance under Hamming:  2.230769230769231
# Percent over Hamming:  97.39999999999999
# Percent under Hamming:  1.3
#
#
#
#
# Starting next K...
# Starting stats for K: 10 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  2.0
# Avg distance underestimated:  8.353671147880041
# E_admiss:  0.033
# E_out:  0.972
# Avg distance over Manhattan:  3.038860103626943
# Avg distance under Manhattan:  3.182377049180328
# Percent over Manhattan:  0.386
# Percent under Manhattan:  0.488
# Avg distance over Hamming:  8.314168377823409
# Avg distance under Hamming:  1.8333333333333333
# Percent over Hamming:  0.974
# Percent under Hamming:  0.012
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.6923076923076923
# Avg distance underestimated:  8.788501026694044
# E_admiss:  2.6
# E_out:  0.976
# Avg distance over Manhattan:  2.837758112094395
# Avg distance under Manhattan:  3.424860853432282
# Percent over Manhattan:  33.900000000000006
# Percent under Manhattan:  53.900000000000006
# Avg distance over Hamming:  7.842105263157895
# Avg distance under Hamming:  2.076923076923077
# Percent over Hamming:  96.89999999999999
# Percent under Hamming:  1.3
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.7222222222222223
# Avg distance underestimated:  9.174134419551935
# E_admiss:  0.018
# E_out:  0.978
# Avg distance over Manhattan:  2.720689655172414
# Avg distance under Manhattan:  3.576214405360134
# Percent over Manhattan:  28.999999999999996
# Percent under Manhattan:  59.699999999999996
# Avg distance over Hamming:  7.393374741200828
# Avg distance under Hamming:  1.7777777777777777
# Percent over Hamming:  96.6
# Percent under Hamming:  1.7999999999999998
#
#
#
#
# Starting next K...
# Starting stats for K: 15 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.6
# Avg distance underestimated:  8.642051282051282
# E_admiss:  0.025
# E_out:  0.978
# Avg distance over Manhattan:  2.737142857142857
# Avg distance under Manhattan:  3.292307692307692
# Percent over Manhattan:  0.35
# Percent under Manhattan:  0.52
# Avg distance over Hamming:  7.91905737704918
# Avg distance under Hamming:  2.076923076923077
# Percent over Hamming:  0.976
# Percent under Hamming:  0.013
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.411764705882353
# Avg distance underestimated:  9.093591047812819
# E_admiss:  1.7000000000000002
# E_out:  0.98
# Avg distance over Manhattan:  2.65625
# Avg distance under Manhattan:  3.5128644939965694
# Percent over Manhattan:  28.799999999999997
# Percent under Manhattan:  58.3
# Avg distance over Hamming:  7.430927835051547
# Avg distance under Hamming:  2.0588235294117645
# Percent over Hamming:  97.0
# Percent under Hamming:  1.7000000000000002
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.2307692307692308
# Avg distance underestimated:  9.55420466058764
# E_admiss:  0.013
# E_out:  0.981
# Avg distance over Manhattan:  2.4688796680497926
# Avg distance under Manhattan:  3.6967340590979783
# Percent over Manhattan:  24.099999999999998
# Percent under Manhattan:  64.3
# Avg distance over Hamming:  6.973001038421599
# Avg distance under Hamming:  1.8636363636363635
# Percent over Hamming:  96.3
# Percent under Hamming:  2.1999999999999997
#
#
#
#
# Starting next K...
# Starting stats for K: 20 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.3636363636363635
# Avg distance underestimated:  8.787321063394684
# E_admiss:  0.022
# E_out:  0.981
# Avg distance over Manhattan:  2.621212121212121
# Avg distance under Manhattan:  3.321626617375231
# Percent over Manhattan:  0.33
# Percent under Manhattan:  0.541
# Avg distance over Hamming:  7.762589928057554
# Avg distance under Hamming:  2.0714285714285716
# Percent over Hamming:  0.973
# Percent under Hamming:  0.014
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.2
# Avg distance underestimated:  9.299492385786802
# E_admiss:  1.5
# E_out:  0.981
# Avg distance over Manhattan:  2.4375
# Avg distance under Manhattan:  3.568144499178982
# Percent over Manhattan:  27.200000000000003
# Percent under Manhattan:  60.9
# Avg distance over Hamming:  7.2424870466321245
# Avg distance under Hamming:  2.0476190476190474
# Percent over Hamming:  96.5
# Percent under Hamming:  2.1
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.1
# Avg distance underestimated:  9.758585858585858
# E_admiss:  0.01
# E_out:  0.986
# Avg distance over Manhattan:  2.2882882882882885
# Avg distance under Manhattan:  3.8042168674698793
# Percent over Manhattan:  22.2
# Percent under Manhattan:  66.4
# Avg distance over Hamming:  6.81112277019937
# Avg distance under Hamming:  2.0384615384615383
# Percent over Hamming:  95.3
# Percent under Hamming:  2.6
#
#
#
#
# Starting next K...
# Starting stats for K: 25 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.588235294117647
# Avg distance underestimated:  8.921668362156664
# E_admiss:  0.017
# E_out:  0.978
# Avg distance over Manhattan:  2.4465408805031448
# Avg distance under Manhattan:  3.391382405745063
# Percent over Manhattan:  0.318
# Percent under Manhattan:  0.557
# Avg distance over Hamming:  7.608247422680412
# Avg distance under Hamming:  1.9444444444444444
# Percent over Hamming:  0.97
# Percent under Hamming:  0.018
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.1818181818181819
# Avg distance underestimated:  9.455005055611728
# E_admiss:  1.0999999999999999
# E_out:  0.986
# Avg distance over Manhattan:  2.352
# Avg distance under Manhattan:  3.584375
# Percent over Manhattan:  25.0
# Percent under Manhattan:  64.0
# Avg distance over Hamming:  7.10125260960334
# Avg distance under Hamming:  2.12
# Percent over Hamming:  95.8
# Percent under Hamming:  2.5
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  10.023255813953488
# E_admiss:  0.011
# E_out:  0.991
# Avg distance over Manhattan:  2.2538860103626943
# Avg distance under Manhattan:  3.914616497829233
# Percent over Manhattan:  19.3
# Percent under Manhattan:  69.1
# Avg distance over Hamming:  6.586497890295359
# Avg distance under Hamming:  2.0714285714285716
# Percent over Hamming:  94.8
# Percent under Hamming:  2.8000000000000003
#
#
#
#
# Starting next K...
# Starting stats for K: 30 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.2666666666666666
# Avg distance underestimated:  9.073096446700507
# E_admiss:  0.015
# E_out:  0.982
# Avg distance over Manhattan:  2.410774410774411
# Avg distance under Manhattan:  3.4817391304347827
# Percent over Manhattan:  0.297
# Percent under Manhattan:  0.575
# Avg distance over Hamming:  7.445247933884297
# Avg distance under Hamming:  1.9473684210526316
# Percent over Hamming:  0.968
# Percent under Hamming:  0.019
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.1818181818181819
# Avg distance underestimated:  9.647118301314459
# E_admiss:  1.0999999999999999
# E_out:  0.987
# Avg distance over Manhattan:  2.327433628318584
# Avg distance under Manhattan:  3.692073170731707
# Percent over Manhattan:  22.6
# Percent under Manhattan:  65.60000000000001
# Avg distance over Hamming:  6.924607329842932
# Avg distance under Hamming:  2.0384615384615383
# Percent over Hamming:  95.5
# Percent under Hamming:  2.6
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  10.11959798994975
# E_admiss:  0.005
# E_out:  0.988
# Avg distance over Manhattan:  2.2134831460674156
# Avg distance under Manhattan:  3.9524475524475524
# Percent over Manhattan:  17.8
# Percent under Manhattan:  71.5
# Avg distance over Hamming:  6.458112407211028
# Avg distance under Hamming:  2.129032258064516
# Percent over Hamming:  94.3
# Percent under Hamming:  3.1
#
#
#
#
# Starting next K...
# Starting stats for K: 35 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.1333333333333333
# Avg distance underestimated:  9.186802030456853
# E_admiss:  0.015
# E_out:  0.987
# Avg distance over Manhattan:  2.3013698630136985
# Avg distance under Manhattan:  3.441860465116279
# Percent over Manhattan:  0.292
# Percent under Manhattan:  0.602
# Avg distance over Hamming:  7.3058702368692074
# Avg distance under Hamming:  2.111111111111111
# Percent over Hamming:  0.971
# Percent under Hamming:  0.018
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  9.697487437185929
# E_admiss:  0.5
# E_out:  0.983
# Avg distance over Manhattan:  2.3130841121495327
# Avg distance under Manhattan:  3.764264264264264
# Percent over Manhattan:  21.4
# Percent under Manhattan:  66.60000000000001
# Avg distance over Hamming:  6.80607966457023
# Avg distance under Hamming:  2.227272727272727
# Percent over Hamming:  95.39999999999999
# Percent under Hamming:  2.1999999999999997
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  10.265531062124248
# E_admiss:  0.002
# E_out:  0.987
# Avg distance over Manhattan:  2.139393939393939
# Avg distance under Manhattan:  4.065843621399177
# Percent over Manhattan:  16.5
# Percent under Manhattan:  72.89999999999999
# Avg distance over Hamming:  6.344420600858369
# Avg distance under Hamming:  2.0606060606060606
# Percent over Hamming:  93.2
# Percent under Hamming:  3.3000000000000003
#
#
#
#
# Starting next K...
# Starting stats for K: 50 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.3
# Avg distance underestimated:  9.437373737373738
# E_admiss:  0.01
# E_out:  0.985
# Avg distance over Manhattan:  2.2509505703422055
# Avg distance under Manhattan:  3.594976452119309
# Percent over Manhattan:  0.263
# Percent under Manhattan:  0.637
# Avg distance over Hamming:  7.091762252346194
# Avg distance under Hamming:  1.9545454545454546
# Percent over Hamming:  0.959
# Percent under Hamming:  0.022
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.1428571428571428
# Avg distance underestimated:  10.09667673716012
# E_admiss:  0.7000000000000001
# E_out:  0.992
# Avg distance over Manhattan:  2.1736842105263157
# Avg distance under Manhattan:  3.970212765957447
# Percent over Manhattan:  19.0
# Percent under Manhattan:  70.5
# Avg distance over Hamming:  6.543223052294557
# Avg distance under Hamming:  1.8484848484848484
# Percent over Hamming:  93.7
# Percent under Hamming:  3.3000000000000003
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  10.63791374122367
# E_admiss:  0.003
# E_out:  0.988
# Avg distance over Manhattan:  2.0215827338129495
# Avg distance under Manhattan:  4.312997347480106
# Percent over Manhattan:  13.900000000000002
# Percent under Manhattan:  75.4
# Avg distance over Hamming:  6.113062568605928
# Avg distance under Hamming:  1.9534883720930232
# Percent over Hamming:  91.10000000000001
# Percent under Hamming:  4.3
#
#
#
#
# Starting next K...
# Starting stats for K: 100 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.2857142857142858
# Avg distance underestimated:  10.021148036253777
# E_admiss:  0.007
# E_out:  0.992
# Avg distance over Manhattan:  2.0195121951219512
# Avg distance under Manhattan:  3.874822190611664
# Percent over Manhattan:  0.205
# Percent under Manhattan:  0.703
# Avg distance over Hamming:  6.579003181336161
# Avg distance under Hamming:  1.6571428571428573
# Percent over Hamming:  0.943
# Percent under Hamming:  0.035
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.25
# Avg distance underestimated:  10.742971887550201
# E_admiss:  0.4
# E_out:  0.994
# Avg distance over Manhattan:  1.9767441860465116
# Avg distance under Manhattan:  4.3203125
# Percent over Manhattan:  12.9
# Percent under Manhattan:  76.8
# Avg distance over Hamming:  6.001092896174863
# Avg distance under Hamming:  1.9215686274509804
# Percent over Hamming:  91.5
# Percent under Hamming:  5.1
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  11.39039039039039
# E_admiss:  0.001
# E_out:  0.992
# Avg distance over Manhattan:  1.8941176470588235
# Avg distance under Manhattan:  4.662291169451074
# Percent over Manhattan:  8.5
# Percent under Manhattan:  83.8
# Avg distance over Hamming:  5.517633674630262
# Avg distance under Hamming:  2.0588235294117645
# Percent over Hamming:  87.9
# Percent under Hamming:  6.800000000000001
#
#
#
#
# Starting next K...
# Starting stats for K: 300 ...
# ------ TRUCATION - KNN with Mean: ------
# Avg distance overestimated:  1.2857142857142858
# Avg distance underestimated:  11.08761329305136
# E_admiss:  0.007
# E_out:  0.996
# Avg distance over Manhattan:  1.776
# Avg distance under Manhattan:  4.539823008849558
# Percent over Manhattan:  0.125
# Percent under Manhattan:  0.791
# Avg distance over Hamming:  5.727373068432671
# Avg distance under Hamming:  1.9615384615384615
# Percent over Hamming:  0.906
# Percent under Hamming:  0.052
#
#
# ------ TRUCATION - KNN with Gmean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  11.95691382765531
# E_admiss:  0.2
# E_out:  0.993
# Avg distance over Manhattan:  1.7096774193548387
# Avg distance under Manhattan:  5.1042873696407876
# Percent over Manhattan:  6.2
# Percent under Manhattan:  86.3
# Avg distance over Hamming:  5.0889929742388755
# Avg distance under Hamming:  2.1
# Percent over Hamming:  85.39999999999999
# Percent under Hamming:  9.0
#
#
# ------ TRUCATION - KNN with HMean: ------
# Avg distance overestimated:  1.0
# Avg distance underestimated:  12.794794794794795
# E_admiss:  0.001
# E_out:  0.994
# Avg distance over Manhattan:  1.71875
# Avg distance under Manhattan:  5.675027262813522
# Percent over Manhattan:  3.2
# Percent under Manhattan:  91.7
# Avg distance over Hamming:  4.481987577639751
# Avg distance under Hamming:  2.263157894736842
# Percent over Hamming:  80.5
# Percent under Hamming:  13.3

# %%
# Matplotlib Plotting

fig = plt.figure(figsize=(5, 3))
plt.plot(K, avg_e_admiss_mean, label='Mean')
plt.plot(K, avg_e_admiss_gmean, label='Geometric Mean')
plt.plot(K, avg_e_admiss_mode, label='Harmonic Mean')
plt.legend()
plt.title("K neighbors vs Non-Admissability")
plt.xlabel("K neighbors")
plt.ylabel("% Overestimated Actual")
plt.show()

'''
Removed this plot/metric after development.
To reinstate, would need to create relavant
lists and append respective values inside the loop.

fig = plt.figure(figsize=(5, 3))
plt.plot(K, avg_dist_over_mean, label='Mean')
plt.plot(K, avg_dist_over_gmean, label='Geometric Mean')
plt.plot(K, avg_dist_over_mode, label='HMean')
plt.legend()
plt.title("K neighbors vs Distance Over Actual")
plt.xlabel("K neighbors")
plt.ylabel("Avg Distance Over Actual")
plt.show()
'''

plt.figure(figsize=(5, 3))
plt.plot(K, perc_over_man_mean, label='Mean')
plt.plot(K, perc_over_man_gmean, label='Geometric Mean')
plt.plot(K, perc_over_man_mode, label='Harmonic Mean')
plt.legend()
plt.title("K neighbors vs Overestimation of Manhattan")
plt.xlabel("K neighbors")
plt.ylabel("% Overestimated Manhattan")
plt.show()

plt.figure(figsize=(5, 3))
plt.plot(K, perc_under_man_mean, label='Mean')
plt.plot(K, perc_under_man_gmean, label='Geometric Mean')
plt.plot(K, perc_under_man_mode, label='Harmonic Mean')
plt.legend()
plt.title("K neighbors vs Underestimation of Manhattan")
plt.xlabel("K neighbors")
plt.ylabel("% Underestimated Manhattan")
plt.show()

plt.figure(figsize=(5, 3))
plt.plot(K, perc_over_ham_mean, label='Mean')
plt.plot(K, perc_over_ham_gmean, label='Geometric Mean')
plt.plot(K, perc_over_ham_mode, label='Harmonic Mean')
plt.legend()
plt.title("K neighbors vs Overestimation of Hamming")
plt.xlabel("K neighbors")
plt.ylabel("% Overestimated Hamming")
plt.show()
